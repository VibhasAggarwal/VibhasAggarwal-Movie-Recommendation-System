# %% [markdown]
# <a href="https://colab.research.google.com/github/VibhasAggarwal/VibhasAggarwal-Movie-Recommendation-System/blob/main/Movierecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies = pd.read_csv('Movies_Dataset.csv')

# %% [markdown]
# # Task
# how do i add this dataset in this code
#
# Here is all the data you need:
# "Movies_Dataset.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the "Movies_Dataset.csv" file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the "Movies_Dataset.csv" file into a pandas DataFrame and display the first few rows to verify.

# %%
import pandas as pd

try:
    df_movies = pd.read_csv('Movies_Dataset.csv')
    display(df_movies.head())
except FileNotFoundError:
    print("Error: 'Movies_Dataset.csv' not found. Please ensure the file exists in the current directory or provide the correct path.")
    df_movies = None  # Assign None to indicate failure
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file. Please check the file format.")
    df_movies = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df_movies = None
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded movie DataFrame (`df_movies`) to understand its structure and identify potential data quality issues.

# %% [markdown]
# **Reasoning**:
# I need to explore the DataFrame `df_movies` to understand its structure, data types, missing values, descriptive statistics, and unique values in each column.  This will help identify potential data quality issues.

# %%
# Examine the shape of the DataFrame
print("Shape of the DataFrame:", df_movies.shape)

# Display data types of each column
print("\nData Types:\n", df_movies.dtypes)

# Check for missing values
print("\nMissing Values:\n", df_movies.isnull().sum())

# Descriptive statistics for numerical columns (if any)
numerical_cols = df_movies.select_dtypes(include=['number'])
if not numerical_cols.empty:
    print("\nDescriptive Statistics for Numerical Columns:\n", numerical_cols.describe())
else:
    print("\nNo numerical columns found.")

# Explore unique values and frequencies for categorical columns
categorical_cols = df_movies.select_dtypes(include=['object'])
for col in categorical_cols.columns:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df_movies[col].value_counts())
    print("-" * 20)

# Examine the first and last few rows
print("\nFirst few rows:\n", df_movies.head())
print("\nLast few rows:\n", df_movies.tail())

# Summarize findings
print("\nSummary:")
print(f"The dataset has {df_movies.shape[0]} rows and {df_movies.shape[1]} columns.")
# Add more details about data types, missing values, and potential outliers/high cardinality to the summary based on the results above.
# Out:
# Shape of the DataFrame: (4803, 4)
#
# Data Types:
#  movie_id     int64
# title       object
# cast        object
# crew        object
# dtype: object
#
# Missing Values:
#  movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64
#
# Descriptive Statistics for Numerical Columns:
#              movie_id
# count    4803.000000
# mean    57165.484281
# std     88694.614033
# min         5.000000
# 25%      9014.500000
# 50%     14629.000000
# 75%     58610.500000
# max    459488.000000
#
# Unique values and frequencies for 'title':
# title
# The Host            2
# Batman              2
# Out of the Blue     2
# Awake               1
# Beneath Hill 60     1
#                    ..
# Drag Me to Hell     1
# Southpaw            1
# Sicario             1
# Glory Road          1
# 30 Days of Night    1
# Name: count, Length: 4800, dtype: int64
# --------------------
#
# Unique values and frequencies for 'cast':
# cast
# ...

# %% [markdown]
# **Reasoning**:
# The previous command's output was truncated. I need to complete the analysis by examining the rest of the unique value counts for the 'cast' and 'crew' columns, and then provide a summary of the findings.

# %%
# Continue displaying unique values and frequencies (truncated in previous output)
for col in ['cast', 'crew']:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df_movies[col].value_counts())
    print("-" * 20)

# Examine the first and last few rows (already done in the previous block, but including here for completeness)
print("\nFirst few rows:\n", df_movies.head())
print("\nLast few rows:\n", df_movies.tail())

# Summarize findings
print("\nSummary:")
print(f"The dataset has {df_movies.shape[0]} rows and {df_movies.shape[1]} columns.")
print("Data types: movie_id (int64), title (object), cast (object), crew (object)")
print("No missing values found in any column.")
print("The 'movie_id' column appears to be numerical, with a range from 5 to 459488.")
print("The 'title' column has some duplicate movie titles.")
print("The 'cast' and 'crew' columns are of object type, likely containing lists or strings. Further investigation is needed to understand their detailed structure.")
# Out:
# Unique values and frequencies for 'cast':
# cast
# ...

# %% [markdown]
# **Reasoning**:
# The previous command's output was again truncated.  I need to complete the analysis by examining the rest of the unique value counts for the 'cast' and 'crew' columns and provide a summary.  Then I can finish the task.

# %%
# Continue displaying unique values and frequencies (truncated in previous output)
for col in ['cast', 'crew']:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df_movies[col].value_counts(dropna=False)) # Include NaN values in the count
    print("-" * 20)

# Summarize findings
print("\nSummary:")
print(f"The dataset has {df_movies.shape[0]} rows and {df_movies.shape[1]} columns.")
print("Data types: movie_id (int64), title (object), cast (object), crew (object)")
print("No missing values found in any column.")
print("The 'movie_id' column appears to be numerical, with a range from 5 to 459488.")
print("The 'title' column has some duplicate movie titles.")
print("The 'cast' and 'crew' columns are of object type, likely containing lists or strings. Further investigation is needed to understand their detailed structure.  The value counts show a high degree of variation in the cast and crew information.")
# Out:
# Unique values and frequencies for 'cast':
# cast
# ...

# %% [markdown]
# **Reasoning**:
# The output is still truncated. I will try one last time to print the value counts for the 'cast' and 'crew' columns, and then summarize the findings and finish the task.  If this output is also truncated, I will report failure.

# %%
# One last attempt to print the value counts without truncation
pd.set_option("display.max_rows", None)  # Remove the row limit for printing

for col in ['cast', 'crew']:
    print(f"\nUnique values and frequencies for '{col}':")
    print(df_movies[col].value_counts(dropna=False))
    print("-" * 20)

# Summarize findings
print("\nSummary:")
print(f"The dataset has {df_movies.shape[0]} rows and {df_movies.shape[1]} columns.")
print("Data types: movie_id (int64), title (object), cast (object), crew (object)")
print("No missing values found in any column.")
print("The 'movie_id' column appears to be numerical, with a range from 5 to 459488.")
print("The 'title' column has some duplicate movie titles.")
print("The 'cast' and 'crew' columns are of object type, likely containing lists or strings. Further investigation is needed to understand their detailed structure.  The value counts show a high degree of variation in the cast and crew information.")

pd.reset_option("display.max_rows") # Reset the display option
# Out:
# Unique values and frequencies for 'cast':
